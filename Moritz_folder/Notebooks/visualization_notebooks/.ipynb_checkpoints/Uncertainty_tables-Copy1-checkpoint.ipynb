# %%
#import all relevant packages
import torch, torchvision
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torchvision.transforms as transforms
import os.path
from os import path
import torch, torchvision
from prettytable import PrettyTable
plt.rcParams["figure.figsize"] = (20,10)

# %%
#DATA WRANGLING

# load SVHN
BATCH_SIZE_TRAIN_SVHN = 128
BATCH_SIZE_TEST_SVHN = 128

transform_base = [transforms.ToTensor()]

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
    ] + transform_base)

transform_test = transforms.Compose(transform_base)
transform_train = transforms.RandomChoice([transform_train, transform_test])

#'~/data/SVHN'
train_data_SVHN = torchvision.datasets.SVHN('~/data/SVHN', split='train',
                             download=True, transform=transform_train)

#'~/data/SVHN'
test_data_SVHN = torchvision.datasets.SVHN('~/data/SVHN', split='test',
                             download=True, transform=transform_test)

SVHN_train_loader = torch.utils.data.DataLoader(train_data_SVHN, batch_size=BATCH_SIZE_TRAIN_SVHN)
SVHN_test_loader = torch.utils.data.DataLoader(test_data_SVHN, batch_size=BATCH_SIZE_TEST_SVHN)


CIFAR10_trainset = torchvision.datasets.CIFAR10(root='~/data/cifar10', train=True, download=True, transform=transform_train)
CIFAR10_train_loader = torch.utils.data.DataLoader(CIFAR10_trainset, batch_size=BATCH_SIZE_TRAIN_SVHN, shuffle=True, num_workers=2)

#~/data/cifar10
CIFAR10_testset = torchvision.datasets.CIFAR10(root='~/data/cifar10', train=False, download=True, transform=transform_test)
CIFAR10_test_loader = torch.utils.data.DataLoader(CIFAR10_testset, batch_size=BATCH_SIZE_TEST_SVHN, shuffle=False, num_workers=2)

#'~/data/cifar100'
CIFAR100_train = torchvision.datasets.CIFAR100(root='~/data/cifar100', train=True,
                                       download=True, transform=transform_train)
CIFAR100_train_loader = torch.utils.data.DataLoader(CIFAR100_train, batch_size=BATCH_SIZE_TRAIN_SVHN,
                                         shuffle=False)
#'~/data/cifar100'
CIFAR100_test = torchvision.datasets.CIFAR100(root='~/data/cifar100', train=False,
                                       download=True, transform=transform_test)
CIFAR100_test_loader = torch.utils.data.DataLoader(CIFAR100_test, batch_size=BATCH_SIZE_TEST_SVHN,
                                         shuffle=False)
# Out:
# Using downloaded and verified file: /Users/moreez/data/SVHN/train_32x32.mat
# Using downloaded and verified file: /Users/moreez/data/SVHN/test_32x32.mat
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def vggNet(sz, out):
    layers = nn.Sequential()
    layers.add_module('0', nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('1', nn.ReLU())
    layers.add_module('2', nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
    layers.add_module('3', nn.Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('4', nn.ReLU())
    layers.add_module('5', nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
    layers.add_module('6', nn.Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('7', nn.ReLU())
    layers.add_module('8', nn.Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('9', nn.ReLU())
    layers.add_module('10', nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
    layers.add_module('11', nn.Conv2d(256, sz, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('12', nn.ReLU())
    layers.add_module('13', nn.Conv2d(sz, sz, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('14', nn.ReLU())
    layers.add_module('15', nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
    layers.add_module('16', nn.Conv2d(sz, sz, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('17', nn.ReLU())
    layers.add_module('18', nn.Conv2d(sz, sz, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)))
    layers.add_module('19', nn.ReLU())
    layers.add_module('20', nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False))
    # layers.add_module('21', nn.AdaptiveAvgPool2d(output_size=(7, 7)))
    layers.add_module('21', nn.Flatten())
    layers.add_module('22', nn.Dropout(p=0.5, inplace=False))
    layers.add_module('23', nn.Linear(in_features=sz, out_features=sz, bias=True))
    layers.add_module('24', nn.ReLU())
    layers.add_module('25', nn.Dropout(p=0.5, inplace=False))
    layers.add_module('26', nn.Linear(in_features=sz, out_features=sz, bias=True))
    layers.add_module('27', nn.ReLU())
    layers.add_module('28', nn.Linear(in_features=sz, out_features=out, bias=True))
    return layers

# %%
def get_accuracy(output, targets):
    """Helper function to print the accuracy"""
    predictions = output.argmax(dim=1, keepdim=True).view_as(targets)
    return predictions.eq(targets).float().mean().item()

# %%
def meancalc(Hessian_diag_x):
    vals = []
    for entry in Hessian_diag_x:
        mean = torch.mean(entry)
        vals.append(mean.item())
    return vals

for dataset in ['MNIST', 'KMNIST', 'EMNIST', 'FashionMNIST']:
    rowvals = []
    x = PrettyTable()
    x.field_names = ['prior', '0.weight', '0.bias', '3.weight', '3.bias', '7.weight', '7.bias']
    for prior in ['1', '01', '001', '0001', '00001', '000001']:
        layermeans = {
            'one_weight': [],
            'one_bias': [],
            'three_weight': [],
            'three_bias': [],
            'seven_weight': [],
            'seven_bias': [],
        }
        for i in range(1, 11):
            s = i
            
            if dataset == 'MNIST':
                DATAPATH = './Hessians/{}/Hessian_prec{}_seed{}.pth'.format(dataset, prior, s)
            else:
                DATAPATH = './Hessians/{}/{}_Hessian_prec{}_seed{}.pth'.format(dataset, dataset, prior, s)

            XMNIST_NN_Std_prec_x = torch.load(DATAPATH, map_location=torch.device('cpu'))

            mns = meancalc(XMNIST_NN_Std_prec_x)

            layermeans['one_weight'].append(mns[0])
            layermeans['one_bias'].append(mns[1])
            layermeans['three_weight'].append(mns[2])
            layermeans['three_bias'].append(mns[3])
            layermeans['seven_weight'].append(mns[4])
            layermeans['seven_bias'].append(mns[5])

        avgDict = {}
        for k, v in layermeans.items():

            avgDict[k] = round(sum(v) / float(len(v)), 4)

        #print('avg on {} with prior {} is:'.format(dataset, prior), list(avgDict.values()))
        #print()
        dictvals = list(avgDict.values())
        dictvals.insert(0, prior)
        
        
        x.add_row(dictvals)
    print("average unvertainty in {}: ".format(dataset) )
    print(x)
    print()
# Out:
# average unvertainty in MNIST:
# +--------+----------+---------+----------+---------+----------+---------+
# | prior  | 0.weight |  0.bias | 3.weight |  3.bias | 7.weight |  7.bias |
# +--------+----------+---------+----------+---------+----------+---------+
# |   1    |  0.9989  |  0.9945 |  0.9999  |  0.9996 |  0.9954  |  0.9988 |
# |   01   |  3.1284  |  3.0128 |  3.1587  |  3.1483 |  3.0441  |  3.1265 |
# |  001   |  9.1788  |  7.5771 |  9.8925  |  9.5997 |  8.2553  |  9.0651 |
# |  0001  | 20.8763  | 13.0099 | 29.0171  | 24.2665 | 18.1852  | 19.0138 |
# | 00001  | 31.0823  | 15.7159 | 66.6582  | 42.2746 | 34.2091  | 25.4718 |
# | 000001 | 34.9811  | 16.8371 | 112.8993 | 67.5562 | 64.5365  | 27.2228 |
# +--------+----------+---------+----------+---------+----------+---------+
#
# average unvertainty in KMNIST:
# +--------+----------+---------+----------+---------+----------+---------+
# | prior  | 0.weight |  0.bias | 3.weight |  3.bias | 7.weight |  7.bias |
# ...

# %% [markdown]
# ## CIFAR10

# %%
import os.path
from os import path
import torch, torchvision
from prettytable import PrettyTable

for sizee in ['512', '128', '64', '32']:#, '16']:
    rowvals = []
    x = PrettyTable()
    #x.field_names = ['accuracy', '0.weight', '0.bias', '1.weight', '1.bias', '3.weight', '3.bias','6.weight', '6.bias',
    #                '11.weight', '11.bias', '13.weight', '13.bias', '16.weight', '16.bias', '18.weight', '18.bias',
    #                '23.weight', '23.bias', '26.weight', '26.bias', '28.weight', '28.bias']
    x.field_names = ['accuracy','0.weight','1.weight', '3.wght','6.wght',
                    '11.wght', '13.wght', '16.wght', '18.wght',
                    '23.wght', '26.wght', '28.wght']
    #for prior in ['1', '01', '001', '0001', '00001', '000001']:
    for accur in ['60', '70', '80', '90']:
    #for accur in ['60']:
        layermeans = {
            'zero_weight': [],
            #'zero_bias': [],
            'one_weight': [],
            #'one_bias': [],
            'three_weight': [],
            #'three_bias': [],
            'six_weight': [],
            #'six_bias': [],
            'eleven_weight': [],
            #'eleven_bias': [],
            'thirteen_weight': [],
            #'thirteen_bias': [],
            'sixteen_weight': [],
            #'sixteen_bias': [],
            'eighteen_weight': [],
            #'eighteen_bias': [],
            'twentythree_weight': [],
            #'twentythree_bias': [],
            'twentysix_weight': [],
            #'twentysix_bias': [],
            'twentyeight_weight': []
            #'twentyeight_bias': []
        }
        for i in [11]: #range(11, 15):
            s = i
        
            #if dataset == 'MNIST':
            #    DATAPATH = './Hessians/{}/Hessian_prec{}_seed{}.pth'.format(dataset, prior, s)
            #else:
            #    DATAPATH = './Hessians/{}/{}_Hessian_prec{}_seed{}.pth'.format(dataset, dataset, prior, s)
            #if path.exists('/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/{}vggHessian_prec00001_seed{}_accur{}.pth'.format(sizee, s, accur)):
            #    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/{}vggHessian_prec00001_seed{}_accur{}.pth'.format(sizee, s, accur)
            if path.exists('/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/{}vggHessian_prec00001_seed{}_accur{}.pth'.format(sizee, s, accur)):
                DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/{}vggHessian_prec00001_seed{}_accur{}.pth'.format(sizee, s, accur)
                #print(accur)
                
                XMNIST_NN_Std_prec_x = torch.load(DATAPATH, map_location=torch.device('cpu'))

                mns = meancalc(XMNIST_NN_Std_prec_x)

                layermeans['zero_weight'].append(mns[0])
                #layermeans['zero_bias'].append(mns[1])
                layermeans['one_weight'].append(mns[2])
                #layermeans['one_bias'].append(mns[3])
                layermeans['three_weight'].append(mns[4])
                #layermeans['three_bias'].append(mns[5])
                layermeans['six_weight'].append(mns[6])
                #layermeans['six_bias'].append(mns[7])
                layermeans['eleven_weight'].append(mns[8])
                #layermeans['eleven_bias'].append(mns[9])
                layermeans['thirteen_weight'].append(mns[10])
                #layermeans['thirteen_bias'].append(mns[11])
                layermeans['sixteen_weight'].append(mns[12])
                #layermeans['sixteen_bias'].append(mns[13])
                layermeans['eighteen_weight'].append(mns[14])
                #layermeans['eighteen_bias'].append(mns[15])
                layermeans['twentythree_weight'].append(mns[16])
                #layermeans['twentythree_bias'].append(mns[17])
                layermeans['twentysix_weight'].append(mns[18])
                #layermeans['twentysix_bias'].append(mns[19])
                layermeans['twentyeight_weight'].append(mns[20])
                #layermeans['twentyeight_bias'].append(mns[21])
                
                flag = True
            else:
                flag = False
        if flag:
            avgDict = {}
            for k, v in layermeans.items():
                avgDict[k] = round(sum(v) / float(len(v)), 4)

            #print('avg on {} with prior {} is:'.format(dataset, prior), list(avgDict.values()))
            #print()
            dictvals = list(avgDict.values())
            dictvals.insert(0, accur)


            x.add_row(dictvals)
    #print("average unvertainty in {}: ".format(sizee) )
    #print(x)
    print()
    #print(dictvals)
    line, =plt.plot(list(layermeans.keys()), dictvals[1:])
    line.set_label(sizee)
plt.legend()
plt.show()

# %% [markdown]
# ## SVHN

# %%
plt.rcParams["figure.figsize"] = (20,10)
for sizee in ['512', '128', '64', '32', '16']:
    rowvals = []
    x = PrettyTable()
    #x.field_names = ['accuracy', '0.weight', '0.bias', '1.weight', '1.bias', '3.weight', '3.bias','6.weight', '6.bias',
    #                '11.weight', '11.bias', '13.weight', '13.bias', '16.weight', '16.bias', '18.weight', '18.bias',
    #                '23.weight', '23.bias', '26.weight', '26.bias', '28.weight', '28.bias']
    x.field_names = ['accuracy','0.weight','1.weight', '3.wght','6.wght',
                    '11.wght', '13.wght', '16.wght', '18.wght',
                    '23.wght', '26.wght', '28.wght']
    #for prior in ['1', '01', '001', '0001', '00001', '000001']:
    for accur in ['60', '70', '80', '90']:
    #for accur in ['60']:
        layermeans = {
            'zero_weight': [],
            #'zero_bias': [],
            'one_weight': [],
            #'one_bias': [],
            'three_weight': [],
            #'three_bias': [],
            'six_weight': [],
            #'six_bias': [],
            'eleven_weight': [],
            #'eleven_bias': [],
            'thirteen_weight': [],
            #'thirteen_bias': [],
            'sixteen_weight': [],
            #'sixteen_bias': [],
            'eighteen_weight': [],
            #'eighteen_bias': [],
            'twentythree_weight': [],
            #'twentythree_bias': [],
            'twentysix_weight': [],
            #'twentysix_bias': [],
            'twentyeight_weight': []
            #'twentyeight_bias': []
        }
        for i in range(11, 15):
            s = i
        
            #if dataset == 'MNIST':
            #    DATAPATH = './Hessians/{}/Hessian_prec{}_seed{}.pth'.format(dataset, prior, s)
            #else:
            #    DATAPATH = './Hessians/{}/{}_Hessian_prec{}_seed{}.pth'.format(dataset, dataset, prior, s)
            #if path.exists('/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/{}vggHessian_prec00001_seed{}_accur{}.pth'.format(sizee, s, accur)):
            #    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/{}vggHessian_prec00001_seed{}_accur{}.pth'.format(sizee, s, accur)
            if path.exists('/Users/moreez/Desktop/BcThesis/VGG/SVHN/{}vggHessian_prec00001_seed{}_accur{}_.pth'.format(sizee, s, accur)):
                DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/SVHN/{}vggHessian_prec00001_seed{}_accur{}_.pth'.format(sizee, s, accur)
                #print(accur)
                
                XMNIST_NN_Std_prec_x = torch.load(DATAPATH, map_location=torch.device('cpu'))

                mns = meancalc(XMNIST_NN_Std_prec_x)

                layermeans['zero_weight'].append(mns[0])
                #layermeans['zero_bias'].append(mns[1])
                layermeans['one_weight'].append(mns[2])
                #layermeans['one_bias'].append(mns[3])
                layermeans['three_weight'].append(mns[4])
                #layermeans['three_bias'].append(mns[5])
                layermeans['six_weight'].append(mns[6])
                #layermeans['six_bias'].append(mns[7])
                layermeans['eleven_weight'].append(mns[8])
                #layermeans['eleven_bias'].append(mns[9])
                layermeans['thirteen_weight'].append(mns[10])
                #layermeans['thirteen_bias'].append(mns[11])
                layermeans['sixteen_weight'].append(mns[12])
                #layermeans['sixteen_bias'].append(mns[13])
                layermeans['eighteen_weight'].append(mns[14])
                #layermeans['eighteen_bias'].append(mns[15])
                layermeans['twentythree_weight'].append(mns[16])
                #layermeans['twentythree_bias'].append(mns[17])
                layermeans['twentysix_weight'].append(mns[18])
                #layermeans['twentysix_bias'].append(mns[19])
                layermeans['twentyeight_weight'].append(mns[20])
                #layermeans['twentyeight_bias'].append(mns[21])
                
                flag = True
            else:
                flag = False
        if flag:
            avgDict = {}
            for k, v in layermeans.items():
                avgDict[k] = round(sum(v) / float(len(v)), 4)

            #print('avg on {} with prior {} is:'.format(dataset, prior), list(avgDict.values()))
            #print()
            dictvals = list(avgDict.values())
            dictvals.insert(0, accur)


            x.add_row(dictvals)
    #print("average unvertainty in {}: ".format(sizee) )
    #print(x)
    print()
    #print(dictvals)
    line, =plt.plot(list(layermeans.keys()), dictvals[1:])
    line.set_label(sizee)
#plt.legend()
#plt.show()

abgleich = torch.load('/Users/moreez/Desktop/BcThesis/VGG/Hess_newmethod_seed123.pth', map_location=torch.device('cpu'))
mnsx = []
for i, tnsr in enumerate(abgleich):
    if i%2 == 0:
        mnsx.append(torch.mean(tnsr))
        #print(torch.mean(tnsr))
line, = plt.plot(list(layermeans.keys()), mnsx)
line.set_label('8')
plt.legend()
plt.show()

# %% [markdown]
# # plot uncertainty against width

# %% [markdown]
# ## CIFAR100

# %%
widths = ['512', '128','64','32','16', '8', '4', '2']

avg_unc_cifar100 = []
lastlayer_unc_cifar100 = []

for width in widths:
    #if width == '16':
    #    accur = '80'
    #elif width in ['8','4','2']:
    #    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/{}bes_ckpt_seed11.pth'.format(width)
    #else:
    #    accur = '90'
    #if path.exists('/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/{}vggHessian_prec00001_seed11_accur{}.pth'.format(width, accur)):
    #        print(width)    
    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/{}vggHessian_prec00001_seed11_.pth'.format(width)
    print(DATAPATH)
    hess = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    temp = []
    for i, tnsr in enumerate(hess):
        if i%2 == 0:
            temp.append(torch.mean(tnsr).item())
            
    avg_unc_cifar100.append(np.mean(temp))
    lastlayer_unc_cifar100.append(torch.mean(hess[-2]).item())
    
print(avg_unc_cifar100)
print(lastlayer_unc_cifar100)
# Out:
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/512vggHessian_prec00001_seed11_.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/128vggHessian_prec00001_seed11_.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/64vggHessian_prec00001_seed11_.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/32vggHessian_prec00001_seed11_.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/16vggHessian_prec00001_seed11_.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/8vggHessian_prec00001_seed11_.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/4vggHessian_prec00001_seed11_.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/bestHess/2vggHessian_prec00001_seed11_.pth
# [90.73240800337358, 80.40317674116655, 77.66595285589045, 74.10025457902388, 75.85045276988636, 79.39888416637073, 99.6697207364169, 98.33297868208452]
# ...

# %%
#plt.plot(widths, lastlayer_unc_cifar100)
#plt.show()
#plt.plot(widths, avg_unc_cifar100)
#plt.show()

# %% [markdown]
# # CIFAR10

# %%
widths = ['512', '128','64','32','16', '8', '4', '2']

avg_unc_cifar10 = []
lastlayer_unc_cifar10 = []

for width in widths:
    #if width == '16':
    #    accur = '80'
    #elif width in ['8','4','2']:
    #    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/{}bes_ckpt_seed11.pth'.format(width)
    #else:
    #    accur = '90'
    #if path.exists('/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/{}vggHessian_prec00001_seed11_accur{}.pth'.format(width, accur)):
    #        print(width)    
    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/{}best_ckpt_seed11.pth'.format(width)
    print(DATAPATH)
    hess = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    temp = []
    for i, tnsr in enumerate(hess):
        if i%2 == 0:
            temp.append(torch.mean(tnsr).item())
            
    avg_unc_cifar10.append(np.mean(temp))
    lastlayer_unc_cifar10.append(torch.mean(hess[-2]).item())
    
print(avg_unc_cifar10)
print(lastlayer_unc_cifar10)
# Out:
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/512best_ckpt_seed11.pth
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/128best_ckpt_seed11.pth
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/64best_ckpt_seed11.pth
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/32best_ckpt_seed11.pth
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/16best_ckpt_seed11.pth
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/8best_ckpt_seed11.pth
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/4best_ckpt_seed11.pth
# /Users/moreez/Desktop/BcThesis/VGG/exx/Hess/bestHess/2best_ckpt_seed11.pth
# [89.04878408258611, 82.75339993563566, 79.46980805830522, 71.55295909534802, 69.55497984452681, 55.38209845803001, 50.62546036460183, 99.9999771118164]
# [83.10487365722656, 65.73026275634766, 54.97224044799805, 34.850318908691406, 47.37517547607422, 40.372352600097656, 8.490812301635742, 99.9999771118164]

# %%
#plt.plot(widths, lastlayer_unc_cifar10)
#plt.show()
#plt.plot(widths, avg_unc_cifar10)
#plt.show()

# %% [markdown]
# ## SVHN

# %%
widths = ['512', '128','64','32','16', '8', '4', '2']

avg_unc_cifar100_untrained = []
lastlayer_unc_cifar100_untrained = []

for width in widths:
    #if width == '16':
    #    accur = '90'
    #elif width in ['8', '4', '2']:
    #    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/SVHN/achtundvier/{}vggHessian_prec00001_seed234.pth'.format(width)
    #else:
    #    accur = '90'
    #if path.exists('/Users/moreez/Desktop/BcThesis/VGG/SVHN/{}vggHessian_prec00001_seed14_accur{}_.pth'.format(width, accur)):
            #print(width)    
    DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/{}untrainedHessian_prec00001_seed44.pth'.format(width)
    print(DATAPATH)
    hess = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    temp = []
    for i, tnsr in enumerate(hess):
        if i%2 == 0:
            temp.append(torch.mean(tnsr).item())
            
    avg_unc_cifar100_untrained.append(np.mean(temp))
    lastlayer_unc_cifar100_untrained.append(torch.mean(hess[-2]).item())
    
#print(avg_unc)
#print(lastlayer_unc)
# Out:
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/512untrainedHessian_prec00001_seed44.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/128untrainedHessian_prec00001_seed44.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/64untrainedHessian_prec00001_seed44.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/32untrainedHessian_prec00001_seed44.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/16untrainedHessian_prec00001_seed44.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/8untrainedHessian_prec00001_seed44.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/4untrainedHessian_prec00001_seed44.pth
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/2untrainedHessian_prec00001_seed44.pth

# %%
plt.plot(wd[::-1], lastlayer_unc_cifar10_untrained[::-1])
plt.show()
plt.plot(wd[::-1], avg_unc_svhnx_untrained[::-1])
plt.plot(wd[::-1], lastlayer_unc_svhnx[::-1])
plt.show()

# %%
DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/512untrainedHessian_prec00001_seed44.pth'.format(width)
print(DATAPATH)
hess = torch.load(DATAPATH, map_location=torch.device('cpu'))
# Out:
# /Users/moreez/Desktop/BcThesis/VGG/CIFAR100/untrained/512untrainedHessian_prec00001_seed44.pth

# %%
for i, tnsr in enumerate(hess):
    if i%2 != 0:
        print(torch.mean(tnsr))
# Out:
# tensor(94.0734)
# tensor(94.6720)
# tensor(94.8105)
# tensor(94.0232)
# tensor(94.2485)
# tensor(92.5550)
# tensor(89.3290)
# tensor(82.0542)
# tensor(81.2176)
# tensor(63.4815)
# tensor(10.0033)

# %%
for i, tnsr in enumerate(hess):
    if i%2 == 0:
        print(torch.mean(tnsr))
# Out:
# tensor(98.0079)
# tensor(99.8937)
# tensor(99.9417)
# tensor(99.9772)
# tensor(99.9774)
# tensor(99.9942)
# tensor(99.9898)
# tensor(99.9843)
# tensor(99.7844)
# tensor(99.6947)
# tensor(97.2800)

# %%
print(hess[0])
# Out:
# tensor([[[[98.8112, 99.0719, 99.2593],
#           [98.5133, 98.7079, 98.8160],
#           [98.4544, 98.5236, 98.5173]],
#
#          [[99.1647, 99.3958, 99.5222],
#           [98.8780, 99.0512, 99.1021],
#           [98.7954, 98.8522, 98.8103]],
#
#          [[99.1728, 99.3700, 99.4701],
#           [98.8953, 99.0414, 99.0743],
#           [98.8116, 98.8567, 98.8077]]],
#
#
#         [[[96.6046, 96.3859, 96.3815],
#           [96.5460, 96.2881, 96.3544],
#           [96.6974, 96.4489, 96.3873]],
#
#          [[96.8554, 96.6700, 96.6806],
#           [96.8176, 96.5854, 96.6658],
#           [97.0172, 96.7868, 96.7342]],
#
#          [[97.1475, 97.0064, 97.0299],
#           [97.1352, 96.9377, 97.0125],
#           [97.3519, 97.1502, 97.0973]]],
#
#
#         [[[95.8438, 95.6818, 96.1181],
#           [95.8138, 95.3491, 95.9148],
#           [96.3117, 95.8614, 96.2722]],
#
#          [[96.3543, 96.1665, 96.5757],
#           [96.3130, 95.8645, 96.4153],
# ...

# %% [markdown]
# # plot acc againts width

# %% [markdown]
# ## SVHN

# %%
widths = [512, 128, 64, 32, 16, 8, 4, 2]
#widths = [8, 4, 2]
#acc_svhn = []
for width in widths:
    model = vggNet(sz=width)
    if path.exists('/Users/moreez/Desktop/BcThesis/VGG/SVHN/{}best_ckpt_seed11_.pth'.format(width)):
            print(width)    
            DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/SVHN/{}best_ckpt_seed11_.pth'.format(width)
    
    weights = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    model.load_state_dict(weights)
    model.eval()
    acctemp = []
    max_len = len(SVHN_test_loader)
    for batch_idx, (x, y) in enumerate(SVHN_test_loader):
            output = model(x)
            accuracy = get_accuracy(output, y)
            if batch_idx % 30 == 0:
                print(
                    "Batch {}/{} \t".format(batch_idx, max_len) + 
                    "Accuracy %.0f" % (accuracy * 100) + "%"
                )
            acctemp.append(accuracy)

    avg_acc = np.mean(acctemp)
    #acc_svhn.append(avg_acc)
    
print(acc_svhn)
#print(lastlayer_unc)
# Out:
# 512
# Batch 0/204 	Accuracy 96%
# Batch 30/204 	Accuracy 93%
# Batch 60/204 	Accuracy 95%
# Batch 90/204 	Accuracy 96%
# Batch 120/204 	Accuracy 97%
# Batch 150/204 	Accuracy 94%
# Batch 180/204 	Accuracy 91%
# 128
# Batch 0/204 	Accuracy 92%
# Batch 30/204 	Accuracy 91%
# Batch 60/204 	Accuracy 97%
# Batch 90/204 	Accuracy 98%
# Batch 120/204 	Accuracy 97%
# Batch 150/204 	Accuracy 94%
# Batch 180/204 	Accuracy 92%
# 64
# Batch 0/204 	Accuracy 89%
# Batch 30/204 	Accuracy 92%
# Batch 60/204 	Accuracy 92%
# Batch 90/204 	Accuracy 97%
# Batch 120/204 	Accuracy 98%
# Batch 150/204 	Accuracy 95%
# Batch 180/204 	Accuracy 90%
# 32
# Batch 0/204 	Accuracy 92%
# Batch 30/204 	Accuracy 88%
# Batch 60/204 	Accuracy 96%
# Batch 90/204 	Accuracy 95%
# Batch 120/204 	Accuracy 98%
# Batch 150/204 	Accuracy 93%
# Batch 180/204 	Accuracy 92%
# 16
# Batch 0/204 	Accuracy 77%
# Batch 30/204 	Accuracy 74%
# Batch 60/204 	Accuracy 73%
# Batch 90/204 	Accuracy 73%
# Batch 120/204 	Accuracy 73%
# ...

# %%
widths = [512, 128, 64, 32, 16, 8, 4, 2]
#widths = [8, 4, 2]

weightsize_svhn = []
for width in widths:
    model = vggNet(sz=width, out=100)
    if path.exists('/Users/moreez/Desktop/BcThesis/VGG/SVHN/{}best_ckpt_seed11_.pth'.format(width)):
            print(width)    
            DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/SVHN/{}best_ckpt_seed11_.pth'.format(width)
    
    weights = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    #model.load_state_dict(weights)
    #model.eval()
    sztemp = []
    for k in weights.keys():
        if 'weight' in k:
            sztemp.append(torch.mean(weights[k]).item())
    
    weightsize_svhn.append(np.mean(sztemp))
    
print(weightsize_svhn)
#print(lastlayer_unc)
# Out:
# 512
# 128
# 64
# 32
# 16
# 8
# 4
# 2
# [0.00044406672003043985, -4.600786765381186e-05, -0.000898550235433504, -0.003817551596016115, -0.006213179101574828, -0.012518313861536708, 0.008344983042661624, 0.03588800712896045]

# %%
#plt.plot(wd[::-1], lastlayer_unc_svhn[::-1])
#plt.show()
#plt.plot(wd[::-1], avg_unc_svhn[::-1])
#plt.show()

# %%
#plt.plot(wd[::-1], weightsize_svhn[::-1])

# %%
#plt.plot(wd, acc_svhn)

# %%
#plt.plot(acc_svhn[::-1], lastlayer_unc_svhn[::-1])
#plt.plot(acc_svhn[::-1], avg_unc_svhn[::-1])

# %% [markdown]
# ## CIFAR10

# %%
widths = [512, 128, 64, 32, 16, 8, 4, 2]
#widths = [8, 4, 2]

#acc_cifar10 = []
for width in widths:
    model = vggNet(sz=width)
    if path.exists('/Users/moreez/Desktop/BcThesis/VGG/exx/{}best_ckpt_seed11.pth'.format(width)):
            print(width)    
            DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/{}best_ckpt_seed11.pth'.format(width)
    
    weights = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    model.load_state_dict(weights)
    model.eval()
    acctemp = []
    max_len = len(CIFAR10_test_loader)
    for batch_idx, (x, y) in enumerate(CIFAR10_test_loader):
            output = model(x)
            accuracy = get_accuracy(output, y)
            if batch_idx % 30 == 0:
                print(
                    "Batch {}/{} \t".format(batch_idx, max_len) + 
                    "Accuracy %.0f" % (accuracy * 100) + "%"
                )
            acctemp.append(accuracy)

    avg_acc = np.mean(acctemp)
    #acc_cifar10.append(avg_acc)
    
print(acc_cifar10)
#print(lastlayer_unc)
# Out:
# 512
# Batch 0/79 	Accuracy 95%
# Batch 30/79 	Accuracy 91%
# Batch 60/79 	Accuracy 87%
# 128
# Batch 0/79 	Accuracy 96%
# Batch 30/79 	Accuracy 93%
# Batch 60/79 	Accuracy 90%
# 64
# Batch 0/79 	Accuracy 95%
# Batch 30/79 	Accuracy 93%
# Batch 60/79 	Accuracy 91%
# 32
# Batch 0/79 	Accuracy 91%
# Batch 30/79 	Accuracy 91%
# Batch 60/79 	Accuracy 88%
# 16
# Batch 0/79 	Accuracy 75%
# Batch 30/79 	Accuracy 75%
# Batch 60/79 	Accuracy 73%
# 8
# Batch 0/79 	Accuracy 42%
# Batch 30/79 	Accuracy 41%
# Batch 60/79 	Accuracy 27%
# 4
# Batch 0/79 	Accuracy 39%
# Batch 30/79 	Accuracy 34%
# Batch 60/79 	Accuracy 28%
# 2
# Batch 0/79 	Accuracy 7%
# Batch 30/79 	Accuracy 9%
# Batch 60/79 	Accuracy 12%
# [0.9037776898734177, 0.9077333860759493, 0.9021954113924051, 0.8752966772151899, 0.7151898734177216, 0.36342958860759494, 0.339003164556962, 0.10096914556962025]

# %%
widths = [512, 128, 64, 32, 16, 8, 4, 2]
#widths = [8, 4, 2]

weightsize_cifar10 = []
for width in widths:
    model = vggNet(sz=width, out=100)
    if path.exists('/Users/moreez/Desktop/BcThesis/VGG/exx/{}best_ckpt_seed11.pth'.format(width)):
            print(width)    
            DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/exx/{}best_ckpt_seed11.pth'.format(width)
    
    weights = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    #model.load_state_dict(weights)
    #model.eval()
    sztemp = []
    for k in weights.keys():
        if 'weight' in k:
            sztemp.append(torch.mean(weights[k]).item())
    
    weightsize_cifar10.append(np.mean(sztemp))
    
print(weightsize_cifar10)
#print(lastlayer_unc)
# Out:
# 512
# 128
# 64
# 32
# 16
# 8
# 4
# 2
# [-0.0005370131579370122, -0.0005730293442111774, -0.002883317113049667, -0.005775266798805619, -0.0023299970473544818, 0.00987986954648725, 0.004293659850108353, 0.03683875188223531]

# %%
#plt.plot(wd[::-1], lastlayer_unc_cifar10[::-1])
#plt.show()
#plt.plot(wd[::-1], avg_unc_cifar10[::-1])
#plt.show()

# %%
#plt.plot(wd[::-1], weightsize_cifar10[::-1])

# %%
#wd = ['512','128', '64', '32', '16', '8', '4', '2']
#plt.plot(wd[::-1], acc_cifar10[::-1])

# %%
#plt.plot(acc_cifar10[::-1], lastlayer_unc_cifar10[::-1])
#plt.plot(acc_cifar10[::-1], avg_unc_cifar10[::-1])

# %% [markdown]
# # CIFAR100

# %%
widths = [512, 128, 64, 32, 16, 8, 4, 2]
#widths = [8, 4, 2]

#acc_cifar100 = []
for width in widths:
    model = vggNet(sz=width, out=100)
    if path.exists('/Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/{}best_ckpt_seed11_.pth'.format(width)):
            print(width)    
            DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/{}best_ckpt_seed11_.pth'.format(width)
    
    weights = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    model.load_state_dict(weights)
    model.eval()
    acctemp = []
    max_len = len(CIFAR10_test_loader)
    for batch_idx, (x, y) in enumerate(CIFAR100_test_loader):
            output = model(x)
            accuracy = get_accuracy(output, y)
            if batch_idx % 30 == 0:
                print(
                    "Batch {}/{} \t".format(batch_idx, max_len) + 
                    "Accuracy %.0f" % (accuracy * 100) + "%"
                )
            acctemp.append(accuracy)

    avg_acc = np.mean(acctemp)
    #acc_cifar100.append(avg_acc)
    
print(acc_cifar100)
#print(lastlayer_unc)
# Out:
# 512
# Batch 0/79 	Accuracy 67%
# Batch 30/79 	Accuracy 60%
# Batch 60/79 	Accuracy 54%
# 128
# Batch 0/79 	Accuracy 66%
# Batch 30/79 	Accuracy 57%
# Batch 60/79 	Accuracy 50%
# 64
# Batch 0/79 	Accuracy 62%
# Batch 30/79 	Accuracy 58%
# Batch 60/79 	Accuracy 49%
# 32
# Batch 0/79 	Accuracy 28%
# Batch 30/79 	Accuracy 39%
# Batch 60/79 	Accuracy 27%
# 16
# Batch 0/79 	Accuracy 12%
# Batch 30/79 	Accuracy 12%
# Batch 60/79 	Accuracy 9%
# 8
# Batch 0/79 	Accuracy 5%
# Batch 30/79 	Accuracy 2%
# Batch 60/79 	Accuracy 5%
# 4
# Batch 0/79 	Accuracy 1%
# Batch 30/79 	Accuracy 1%
# Batch 60/79 	Accuracy 1%
# 2
# Batch 0/79 	Accuracy 2%
# Batch 30/79 	Accuracy 2%
# Batch 60/79 	Accuracy 1%
# [0.5986946202531646, 0.5959256329113924, 0.5410403481012658, 0.3190268987341772, 0.09731012658227849, 0.04855617088607595, 0.009889240506329115, 0.009889240506329115]

# %%
widths = [512, 128, 64, 32, 16, 8, 4, 2]
#widths = [8, 4, 2]

weightsize_cifar100 = []
for width in widths:
    model = vggNet(sz=width, out=100)
    if path.exists('/Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/{}best_ckpt_seed11_.pth'.format(width)):
            print(width)    
            DATAPATH = '/Users/moreez/Desktop/BcThesis/VGG/CIFAR100/exx/{}best_ckpt_seed11_.pth'.format(width)
    
    weights = torch.load(DATAPATH, map_location=torch.device('cpu')) 
    #model.load_state_dict(weights)
    #model.eval()
    sztemp = []
    for k in weights.keys():
        if 'weight' in k:
            sztemp.append(torch.mean(weights[k]).item())
    
    weightsize_cifar100.append(np.mean(sztemp))
    
print(weightsize_cifar100)
#print(lastlayer_unc)
# Out:
# 512
# 128
# 64
# 32
# 16
# 8
# 4
# 2
# [-0.0008589857794835222, -0.002250067026993334, -0.002378932871331265, -0.002157106562993828, -0.00014604929203249577, -0.027708971304078164, 0.010127729192225326, 0.027009757998381578]

# %%
#plt.plot(wd[::-1], lastlayer_unc_cifar100[::-1])
#plt.show()
#plt.plot(wd[::-1], avg_unc_cifar100[::-1])
#plt.show()

# %%
#plt.plot(wd[::-1], weightsize_cifar100[::-1])

# %%
#plt.plot(wd[::-1], acc_cifar100[::-1])

# %%
#plt.plot(acc_cifar100[::-1], lastlayer_unc_cifar100[::-1])
#plt.plot(acc_cifar100[::-1], avg_unc_cifar100[::-1])

# %% [markdown]
# # PLOTS uncertaint accuracy width

# %% [markdown]
# ## SVHN

# %% [markdown]
# ### width against accuracy

# %%
plt.plot(wd[::-1], acc_svhn[::-1])

# %% [markdown]
# ### width against uncertainty

# %%
fig, = plt.plot(wd[::-1], lastlayer_unc_svhn[::-1])
fig.set_label('last layer')
fig, = plt.plot(wd[::-1], avg_unc_svhn[::-1])
fig.set_label('average')
plt.legend()
plt.show()

# %%
fig, = plt.plot(wd[::-1], lastlayer_unc_svhnx_untrained)
fig.set_label('ll untrained')
fig, = plt.plot(wd[::-1], avg_unc_svhnx_untrained)
fig.set_label('avg untrained')
plt.legend()
plt.show()

# %% [markdown]
# ### width against weightsize

# %%
plt.plot(wd[::-1], weightsize_svhn[::-1])

# %% [markdown]
# ## CIFAR10

# %% [markdown]
# ### width against accuracy

# %%
plt.plot(wd[::-1], acc_cifar10[::-1])

# %% [markdown]
# ### width against uncertainty

# %%
fig, = plt.plot(wd[::-1], lastlayer_unc_cifar10[::-1])
fig.set_label('last layer')
fig, = plt.plot(wd[::-1], avg_unc_cifar10[::-1])
fig.set_label('average')
plt.legend()
plt.show()

# %%
fig, = plt.plot(wd[::-1], lastlayer_unc_cifar10_untrained[::-1])
fig.set_label('ll untrained')
fig, = plt.plot(wd[::-1], avg_unc_cifar10_untrained[::-1])
fig.set_label('avg untrained')
plt.legend()
plt.show()

# %% [markdown]
# ### width against weightsize

# %%
plt.plot(wd[::-1], weightsize_cifar10[::-1])

# %% [markdown]
# ## CIFAR100

# %% [markdown]
# ### width against accuracy

# %%
plt.plot(wd[::-1], acc_cifar100[::-1])

# %% [markdown]
# ### width against uncertainty

# %%
fig, = plt.plot(wd[::-1], lastlayer_unc_cifar100[::-1])
fig.set_label('last layer')
fig, = plt.plot(wd[::-1], avg_unc_cifar100[::-1])
fig.set_label('average')
plt.legend()
plt.show()

# %%
fig, = plt.plot(wd[::-1], lastlayer_unc_cifar100_untrained[::-1])
fig.set_label('ll untrained')
fig, = plt.plot(wd[::-1], avg_unc_cifar100_untrained[::-1])
fig.set_label('avg untrained')
plt.legend()
plt.show()

# %% [markdown]
# ### width against weightsize

# %%
plt.plot(wd[::-1], weightsize_cifar100[::-1])

# %% [markdown]
# ## uncertainty against accuary (SVHN, CIFAR10, CIFAR100 respectively)

# %%
plt.plot(acc_svhn[::-1], lastlayer_unc_svhn[::-1])
plt.plot(acc_svhn[::-1], avg_unc_svhn[::-1])

# %%
plt.plot(acc_cifar10[::-1], lastlayer_unc_cifar10[::-1])
plt.plot(acc_cifar10[::-1], avg_unc_cifar10[::-1])

# %%
plt.plot(acc_cifar100[::-1], lastlayer_unc_cifar100[::-1])
plt.plot(acc_cifar100[::-1], avg_unc_cifar100[::-1])

# %%
#import all relevant packages
import torch, torchvision
import torchvision.transforms as transforms
import numpy as np
from backpack import backpack, extend
from backpack.extensions import DiagHessian
import matplotlib.pyplot as plt
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
from torch.nn import functional as F

s=42
np.random.seed(s)
torch.manual_seed(s)
torch.cuda.manual_seed(s)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Data wrangling

# %%
# data wrangling: load MNIST
MNIST_transform = transforms.Compose([
    transforms.ToTensor(),
])


MNIST_train = torchvision.datasets.MNIST(
        '~/data/mnist',
        train=True,
        download=False,
        transform=MNIST_transform)


MNIST_test = torchvision.datasets.MNIST(
        '~/data/mnist',
        train=False,
        download=False,
        transform=MNIST_transform)

# %%
# have a look at the data to verify
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    #plt.imshow(npimg)
    plt.show()

images = MNIST_train.data[:10].view(10, 1, 28, 28)
imshow(torchvision.utils.make_grid(images, nrow=5))

# %%
mnist_train_loader = torch.utils.data.dataloader.DataLoader(
    MNIST_train,
    batch_size=128,
    shuffle=True
)

mnist_test_loader = torch.utils.data.dataloader.DataLoader(
    MNIST_test,
    batch_size=128,
    shuffle=False,
)

# %% [markdown]
# # Training routine

# %%
#set up the network
def NN(num_classes=10):
    
    features = torch.nn.Sequential(
        torch.nn.Conv2d(1, 32, 5),
        torch.nn.ReLU(),
        torch.nn.MaxPool2d(2,2),
        torch.nn.Conv2d(32, 32, 5),
        torch.nn.ReLU(),
        torch.nn.MaxPool2d(2,2),
        torch.nn.Flatten(),
        torch.nn.Linear(4 * 4 * 32, num_classes)
    )
    return(features)

# %%
#set up the training routine
mnist_model = NN(num_classes=10)
loss_function = torch.nn.CrossEntropyLoss()

mnist_train_optimizer = torch.optim.Adam(mnist_model.parameters(), lr=1e-3, weight_decay=5e-4)
#dont use SGD, it is way worse than Adam here
MNIST_PATH = "MNIST_weights.pth"

# %%
# helper function to get accuracy
def get_accuracy(output, targets):
    """Helper function to print the accuracy"""
    predictions = output.argmax(dim=1, keepdim=True).view_as(targets)
    return predictions.eq(targets).float().mean().item()

# %%
# Write the training routine and save the model at FMNIST_PATH

def train(verbose=False, num_iter=5):
    max_len = len(mnist_train_loader)
    for iter in range(num_iter):
        for batch_idx, (x, y) in enumerate(mnist_train_loader):
            output = mnist_model(x)

            accuracy = get_accuracy(output, y)

            loss = loss_function(output, y)
            loss.backward()
            mnist_train_optimizer.step()
            mnist_train_optimizer.zero_grad()

            if verbose:
                if batch_idx % 10 == 0:
                    print(
                        "Iteration {}; {}/{} \t".format(iter, batch_idx, max_len) +
                        "Minibatch Loss %.3f  " % (loss) +
                        "Accuracy %.0f" % (accuracy * 100) + "%"
                    )

    print("saving model at: {}".format(MNIST_PATH))
    torch.save(mnist_model.state_dict(), MNIST_PATH)

# %%
#after training it once, comment this out to save time if you rerun the entire script
train(verbose=True, num_iter=5)
# Out:
# Iteration 0; 0/469 	Minibatch Loss 2.306  Accuracy 8%
# Iteration 0; 10/469 	Minibatch Loss 1.958  Accuracy 54%
# Iteration 0; 20/469 	Minibatch Loss 1.301  Accuracy 66%
# Iteration 0; 30/469 	Minibatch Loss 0.702  Accuracy 77%
# Iteration 0; 40/469 	Minibatch Loss 0.445  Accuracy 84%
# Iteration 0; 50/469 	Minibatch Loss 0.362  Accuracy 90%
# Iteration 0; 60/469 	Minibatch Loss 0.304  Accuracy 91%
# Iteration 0; 70/469 	Minibatch Loss 0.238  Accuracy 93%
# Iteration 0; 80/469 	Minibatch Loss 0.280  Accuracy 92%
# Iteration 0; 90/469 	Minibatch Loss 0.259  Accuracy 92%
# Iteration 0; 100/469 	Minibatch Loss 0.233  Accuracy 92%
# Iteration 0; 110/469 	Minibatch Loss 0.175  Accuracy 95%
# Iteration 0; 120/469 	Minibatch Loss 0.234  Accuracy 92%
# Iteration 0; 130/469 	Minibatch Loss 0.162  Accuracy 95%
# Iteration 0; 140/469 	Minibatch Loss 0.229  Accuracy 94%
# Iteration 0; 150/469 	Minibatch Loss 0.201  Accuracy 95%
# Iteration 0; 160/469 	Minibatch Loss 0.191  Accuracy 93%
# Iteration 0; 170/469 	Minibatch Loss 0.166  Accuracy 95%
# Iteration 0; 180/469 	Minibatch Loss 0.088  Accuracy 99%
# Iteration 0; 190/469 	Minibatch Loss 0.181  Accuracy 95%
# Iteration 0; 200/469 	Minibatch Loss 0.347  Accuracy 87%
# Iteration 0; 210/469 	Minibatch Loss 0.128  Accuracy 94%
# Iteration 0; 220/469 	Minibatch Loss 0.146  Accuracy 95%
# Iteration 0; 230/469 	Minibatch Loss 0.174  Accuracy 95%
# Iteration 0; 240/469 	Minibatch Loss 0.131  Accuracy 97%
# Iteration 0; 250/469 	Minibatch Loss 0.262  Accuracy 95%
# Iteration 0; 260/469 	Minibatch Loss 0.122  Accuracy 95%
# Iteration 0; 270/469 	Minibatch Loss 0.273  Accuracy 89%
# Iteration 0; 280/469 	Minibatch Loss 0.141  Accuracy 96%
# Iteration 0; 290/469 	Minibatch Loss 0.122  Accuracy 96%
# Iteration 0; 300/469 	Minibatch Loss 0.158  Accuracy 93%
# Iteration 0; 310/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 0; 320/469 	Minibatch Loss 0.091  Accuracy 95%
# Iteration 0; 330/469 	Minibatch Loss 0.123  Accuracy 97%
# Iteration 0; 340/469 	Minibatch Loss 0.080  Accuracy 98%
# Iteration 0; 350/469 	Minibatch Loss 0.096  Accuracy 98%
# Iteration 0; 360/469 	Minibatch Loss 0.135  Accuracy 97%
# Iteration 0; 370/469 	Minibatch Loss 0.142  Accuracy 95%
# Iteration 0; 380/469 	Minibatch Loss 0.235  Accuracy 95%
# Iteration 0; 390/469 	Minibatch Loss 0.104  Accuracy 96%
# Iteration 0; 400/469 	Minibatch Loss 0.095  Accuracy 96%
# Iteration 0; 410/469 	Minibatch Loss 0.038  Accuracy 100%
# Iteration 0; 420/469 	Minibatch Loss 0.091  Accuracy 98%
# Iteration 0; 430/469 	Minibatch Loss 0.065  Accuracy 99%
# Iteration 0; 440/469 	Minibatch Loss 0.137  Accuracy 97%
# Iteration 0; 450/469 	Minibatch Loss 0.139  Accuracy 98%
# Iteration 0; 460/469 	Minibatch Loss 0.108  Accuracy 97%
# Iteration 1; 0/469 	Minibatch Loss 0.090  Accuracy 98%
# Iteration 1; 10/469 	Minibatch Loss 0.111  Accuracy 97%
# Iteration 1; 20/469 	Minibatch Loss 0.044  Accuracy 100%
# Iteration 1; 30/469 	Minibatch Loss 0.083  Accuracy 98%
# Iteration 1; 40/469 	Minibatch Loss 0.082  Accuracy 98%
# Iteration 1; 50/469 	Minibatch Loss 0.093  Accuracy 98%
# Iteration 1; 60/469 	Minibatch Loss 0.154  Accuracy 92%
# Iteration 1; 70/469 	Minibatch Loss 0.049  Accuracy 98%
# Iteration 1; 80/469 	Minibatch Loss 0.063  Accuracy 97%
# Iteration 1; 90/469 	Minibatch Loss 0.173  Accuracy 95%
# Iteration 1; 100/469 	Minibatch Loss 0.095  Accuracy 96%
# Iteration 1; 110/469 	Minibatch Loss 0.094  Accuracy 96%
# Iteration 1; 120/469 	Minibatch Loss 0.036  Accuracy 100%
# Iteration 1; 130/469 	Minibatch Loss 0.057  Accuracy 98%
# Iteration 1; 140/469 	Minibatch Loss 0.035  Accuracy 99%
# Iteration 1; 150/469 	Minibatch Loss 0.041  Accuracy 99%
# Iteration 1; 160/469 	Minibatch Loss 0.114  Accuracy 97%
# Iteration 1; 170/469 	Minibatch Loss 0.085  Accuracy 96%
# Iteration 1; 180/469 	Minibatch Loss 0.080  Accuracy 98%
# Iteration 1; 190/469 	Minibatch Loss 0.108  Accuracy 97%
# Iteration 1; 200/469 	Minibatch Loss 0.080  Accuracy 97%
# Iteration 1; 210/469 	Minibatch Loss 0.066  Accuracy 98%
# Iteration 1; 220/469 	Minibatch Loss 0.104  Accuracy 98%
# Iteration 1; 230/469 	Minibatch Loss 0.111  Accuracy 98%
# Iteration 1; 240/469 	Minibatch Loss 0.079  Accuracy 98%
# Iteration 1; 250/469 	Minibatch Loss 0.067  Accuracy 97%
# Iteration 1; 260/469 	Minibatch Loss 0.115  Accuracy 95%
# Iteration 1; 270/469 	Minibatch Loss 0.080  Accuracy 98%
# Iteration 1; 280/469 	Minibatch Loss 0.087  Accuracy 99%
# Iteration 1; 290/469 	Minibatch Loss 0.093  Accuracy 97%
# Iteration 1; 300/469 	Minibatch Loss 0.055  Accuracy 98%
# Iteration 1; 310/469 	Minibatch Loss 0.050  Accuracy 98%
# Iteration 1; 320/469 	Minibatch Loss 0.009  Accuracy 100%
# Iteration 1; 330/469 	Minibatch Loss 0.017  Accuracy 99%
# Iteration 1; 340/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 1; 350/469 	Minibatch Loss 0.090  Accuracy 95%
# Iteration 1; 360/469 	Minibatch Loss 0.027  Accuracy 99%
# Iteration 1; 370/469 	Minibatch Loss 0.035  Accuracy 99%
# Iteration 1; 380/469 	Minibatch Loss 0.064  Accuracy 96%
# Iteration 1; 390/469 	Minibatch Loss 0.073  Accuracy 98%
# Iteration 1; 400/469 	Minibatch Loss 0.104  Accuracy 98%
# Iteration 1; 410/469 	Minibatch Loss 0.059  Accuracy 99%
# Iteration 1; 420/469 	Minibatch Loss 0.095  Accuracy 96%
# Iteration 1; 430/469 	Minibatch Loss 0.057  Accuracy 98%
# Iteration 1; 440/469 	Minibatch Loss 0.055  Accuracy 98%
# Iteration 1; 450/469 	Minibatch Loss 0.067  Accuracy 97%
# Iteration 1; 460/469 	Minibatch Loss 0.030  Accuracy 100%
# Iteration 2; 0/469 	Minibatch Loss 0.092  Accuracy 98%
# Iteration 2; 10/469 	Minibatch Loss 0.027  Accuracy 99%
# Iteration 2; 20/469 	Minibatch Loss 0.108  Accuracy 95%
# Iteration 2; 30/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 2; 40/469 	Minibatch Loss 0.046  Accuracy 98%
# Iteration 2; 50/469 	Minibatch Loss 0.063  Accuracy 98%
# Iteration 2; 60/469 	Minibatch Loss 0.043  Accuracy 98%
# Iteration 2; 70/469 	Minibatch Loss 0.124  Accuracy 96%
# Iteration 2; 80/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 2; 90/469 	Minibatch Loss 0.031  Accuracy 99%
# Iteration 2; 100/469 	Minibatch Loss 0.034  Accuracy 98%
# Iteration 2; 110/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 2; 120/469 	Minibatch Loss 0.045  Accuracy 99%
# Iteration 2; 130/469 	Minibatch Loss 0.046  Accuracy 98%
# Iteration 2; 140/469 	Minibatch Loss 0.097  Accuracy 96%
# Iteration 2; 150/469 	Minibatch Loss 0.119  Accuracy 98%
# Iteration 2; 160/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 2; 170/469 	Minibatch Loss 0.023  Accuracy 100%
# Iteration 2; 180/469 	Minibatch Loss 0.069  Accuracy 97%
# Iteration 2; 190/469 	Minibatch Loss 0.077  Accuracy 98%
# Iteration 2; 200/469 	Minibatch Loss 0.045  Accuracy 99%
# Iteration 2; 210/469 	Minibatch Loss 0.023  Accuracy 99%
# Iteration 2; 220/469 	Minibatch Loss 0.035  Accuracy 99%
# Iteration 2; 230/469 	Minibatch Loss 0.023  Accuracy 100%
# Iteration 2; 240/469 	Minibatch Loss 0.029  Accuracy 100%
# Iteration 2; 250/469 	Minibatch Loss 0.062  Accuracy 98%
# Iteration 2; 260/469 	Minibatch Loss 0.048  Accuracy 99%
# Iteration 2; 270/469 	Minibatch Loss 0.065  Accuracy 99%
# Iteration 2; 280/469 	Minibatch Loss 0.048  Accuracy 99%
# Iteration 2; 290/469 	Minibatch Loss 0.017  Accuracy 100%
# Iteration 2; 300/469 	Minibatch Loss 0.017  Accuracy 99%
# Iteration 2; 310/469 	Minibatch Loss 0.064  Accuracy 98%
# Iteration 2; 320/469 	Minibatch Loss 0.148  Accuracy 96%
# Iteration 2; 330/469 	Minibatch Loss 0.032  Accuracy 99%
# Iteration 2; 340/469 	Minibatch Loss 0.034  Accuracy 98%
# Iteration 2; 350/469 	Minibatch Loss 0.019  Accuracy 100%
# Iteration 2; 360/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 2; 370/469 	Minibatch Loss 0.102  Accuracy 98%
# Iteration 2; 380/469 	Minibatch Loss 0.023  Accuracy 100%
# Iteration 2; 390/469 	Minibatch Loss 0.018  Accuracy 99%
# Iteration 2; 400/469 	Minibatch Loss 0.037  Accuracy 99%
# Iteration 2; 410/469 	Minibatch Loss 0.122  Accuracy 97%
# Iteration 2; 420/469 	Minibatch Loss 0.037  Accuracy 99%
# Iteration 2; 430/469 	Minibatch Loss 0.097  Accuracy 96%
# Iteration 2; 440/469 	Minibatch Loss 0.036  Accuracy 99%
# Iteration 2; 450/469 	Minibatch Loss 0.027  Accuracy 100%
# Iteration 2; 460/469 	Minibatch Loss 0.082  Accuracy 97%
# Iteration 3; 0/469 	Minibatch Loss 0.018  Accuracy 99%
# Iteration 3; 10/469 	Minibatch Loss 0.030  Accuracy 98%
# Iteration 3; 20/469 	Minibatch Loss 0.058  Accuracy 98%
# Iteration 3; 30/469 	Minibatch Loss 0.020  Accuracy 100%
# Iteration 3; 40/469 	Minibatch Loss 0.045  Accuracy 98%
# Iteration 3; 50/469 	Minibatch Loss 0.092  Accuracy 95%
# Iteration 3; 60/469 	Minibatch Loss 0.110  Accuracy 97%
# Iteration 3; 70/469 	Minibatch Loss 0.064  Accuracy 98%
# Iteration 3; 80/469 	Minibatch Loss 0.017  Accuracy 99%
# Iteration 3; 90/469 	Minibatch Loss 0.069  Accuracy 97%
# Iteration 3; 100/469 	Minibatch Loss 0.196  Accuracy 98%
# Iteration 3; 110/469 	Minibatch Loss 0.035  Accuracy 99%
# Iteration 3; 120/469 	Minibatch Loss 0.013  Accuracy 100%
# Iteration 3; 130/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 3; 140/469 	Minibatch Loss 0.046  Accuracy 99%
# Iteration 3; 150/469 	Minibatch Loss 0.043  Accuracy 98%
# Iteration 3; 160/469 	Minibatch Loss 0.025  Accuracy 99%
# Iteration 3; 170/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 3; 180/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 3; 190/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 3; 200/469 	Minibatch Loss 0.075  Accuracy 98%
# Iteration 3; 210/469 	Minibatch Loss 0.038  Accuracy 98%
# Iteration 3; 220/469 	Minibatch Loss 0.038  Accuracy 98%
# Iteration 3; 230/469 	Minibatch Loss 0.021  Accuracy 99%
# Iteration 3; 240/469 	Minibatch Loss 0.063  Accuracy 97%
# Iteration 3; 250/469 	Minibatch Loss 0.021  Accuracy 100%
# Iteration 3; 260/469 	Minibatch Loss 0.037  Accuracy 98%
# Iteration 3; 270/469 	Minibatch Loss 0.081  Accuracy 98%
# Iteration 3; 280/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 3; 290/469 	Minibatch Loss 0.045  Accuracy 98%
# Iteration 3; 300/469 	Minibatch Loss 0.029  Accuracy 99%
# Iteration 3; 310/469 	Minibatch Loss 0.046  Accuracy 98%
# Iteration 3; 320/469 	Minibatch Loss 0.036  Accuracy 99%
# Iteration 3; 330/469 	Minibatch Loss 0.129  Accuracy 98%
# Iteration 3; 340/469 	Minibatch Loss 0.058  Accuracy 98%
# Iteration 3; 350/469 	Minibatch Loss 0.030  Accuracy 98%
# Iteration 3; 360/469 	Minibatch Loss 0.074  Accuracy 99%
# Iteration 3; 370/469 	Minibatch Loss 0.031  Accuracy 100%
# Iteration 3; 380/469 	Minibatch Loss 0.025  Accuracy 99%
# Iteration 3; 390/469 	Minibatch Loss 0.044  Accuracy 98%
# Iteration 3; 400/469 	Minibatch Loss 0.037  Accuracy 98%
# Iteration 3; 410/469 	Minibatch Loss 0.055  Accuracy 98%
# Iteration 3; 420/469 	Minibatch Loss 0.054  Accuracy 98%
# Iteration 3; 430/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 3; 440/469 	Minibatch Loss 0.059  Accuracy 98%
# Iteration 3; 450/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 3; 460/469 	Minibatch Loss 0.040  Accuracy 98%
# Iteration 4; 0/469 	Minibatch Loss 0.021  Accuracy 99%
# Iteration 4; 10/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 4; 20/469 	Minibatch Loss 0.053  Accuracy 99%
# Iteration 4; 30/469 	Minibatch Loss 0.026  Accuracy 99%
# Iteration 4; 40/469 	Minibatch Loss 0.019  Accuracy 100%
# Iteration 4; 50/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 4; 60/469 	Minibatch Loss 0.053  Accuracy 98%
# Iteration 4; 70/469 	Minibatch Loss 0.057  Accuracy 98%
# Iteration 4; 80/469 	Minibatch Loss 0.017  Accuracy 99%
# Iteration 4; 90/469 	Minibatch Loss 0.116  Accuracy 98%
# Iteration 4; 100/469 	Minibatch Loss 0.024  Accuracy 100%
# Iteration 4; 110/469 	Minibatch Loss 0.064  Accuracy 97%
# Iteration 4; 120/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 4; 130/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 4; 140/469 	Minibatch Loss 0.034  Accuracy 98%
# Iteration 4; 150/469 	Minibatch Loss 0.125  Accuracy 96%
# Iteration 4; 160/469 	Minibatch Loss 0.053  Accuracy 99%
# Iteration 4; 170/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 4; 180/469 	Minibatch Loss 0.034  Accuracy 99%
# Iteration 4; 190/469 	Minibatch Loss 0.019  Accuracy 98%
# Iteration 4; 200/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 4; 210/469 	Minibatch Loss 0.025  Accuracy 99%
# Iteration 4; 220/469 	Minibatch Loss 0.021  Accuracy 98%
# Iteration 4; 230/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 4; 240/469 	Minibatch Loss 0.024  Accuracy 100%
# Iteration 4; 250/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 4; 260/469 	Minibatch Loss 0.021  Accuracy 99%
# Iteration 4; 270/469 	Minibatch Loss 0.012  Accuracy 99%
# Iteration 4; 280/469 	Minibatch Loss 0.049  Accuracy 98%
# Iteration 4; 290/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 4; 300/469 	Minibatch Loss 0.050  Accuracy 98%
# Iteration 4; 310/469 	Minibatch Loss 0.009  Accuracy 100%
# Iteration 4; 320/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 4; 330/469 	Minibatch Loss 0.043  Accuracy 98%
# Iteration 4; 340/469 	Minibatch Loss 0.054  Accuracy 98%
# Iteration 4; 350/469 	Minibatch Loss 0.035  Accuracy 99%
# Iteration 4; 360/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 4; 370/469 	Minibatch Loss 0.041  Accuracy 98%
# Iteration 4; 380/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 4; 390/469 	Minibatch Loss 0.030  Accuracy 98%
# Iteration 4; 400/469 	Minibatch Loss 0.172  Accuracy 96%
# Iteration 4; 410/469 	Minibatch Loss 0.016  Accuracy 99%
# Iteration 4; 420/469 	Minibatch Loss 0.033  Accuracy 99%
# Iteration 4; 430/469 	Minibatch Loss 0.013  Accuracy 100%
# Iteration 4; 440/469 	Minibatch Loss 0.024  Accuracy 98%
# Iteration 4; 450/469 	Minibatch Loss 0.016  Accuracy 100%
# Iteration 4; 460/469 	Minibatch Loss 0.020  Accuracy 100%
# Iteration 5; 0/469 	Minibatch Loss 0.014  Accuracy 100%
# Iteration 5; 10/469 	Minibatch Loss 0.062  Accuracy 96%
# Iteration 5; 20/469 	Minibatch Loss 0.067  Accuracy 98%
# Iteration 5; 30/469 	Minibatch Loss 0.024  Accuracy 99%
# Iteration 5; 40/469 	Minibatch Loss 0.031  Accuracy 100%
# Iteration 5; 50/469 	Minibatch Loss 0.026  Accuracy 98%
# Iteration 5; 60/469 	Minibatch Loss 0.027  Accuracy 99%
# Iteration 5; 70/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 5; 80/469 	Minibatch Loss 0.090  Accuracy 97%
# Iteration 5; 90/469 	Minibatch Loss 0.021  Accuracy 99%
# Iteration 5; 100/469 	Minibatch Loss 0.018  Accuracy 99%
# Iteration 5; 110/469 	Minibatch Loss 0.028  Accuracy 99%
# Iteration 5; 120/469 	Minibatch Loss 0.098  Accuracy 97%
# Iteration 5; 130/469 	Minibatch Loss 0.015  Accuracy 99%
# Iteration 5; 140/469 	Minibatch Loss 0.040  Accuracy 98%
# Iteration 5; 150/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 5; 160/469 	Minibatch Loss 0.120  Accuracy 97%
# Iteration 5; 170/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 5; 180/469 	Minibatch Loss 0.035  Accuracy 98%
# Iteration 5; 190/469 	Minibatch Loss 0.031  Accuracy 99%
# Iteration 5; 200/469 	Minibatch Loss 0.069  Accuracy 98%
# Iteration 5; 210/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 5; 220/469 	Minibatch Loss 0.018  Accuracy 99%
# Iteration 5; 230/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 5; 240/469 	Minibatch Loss 0.024  Accuracy 99%
# Iteration 5; 250/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 5; 260/469 	Minibatch Loss 0.083  Accuracy 97%
# Iteration 5; 270/469 	Minibatch Loss 0.027  Accuracy 99%
# Iteration 5; 280/469 	Minibatch Loss 0.032  Accuracy 99%
# Iteration 5; 290/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 5; 300/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 5; 310/469 	Minibatch Loss 0.082  Accuracy 98%
# Iteration 5; 320/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 5; 330/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 5; 340/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 5; 350/469 	Minibatch Loss 0.014  Accuracy 100%
# Iteration 5; 360/469 	Minibatch Loss 0.009  Accuracy 100%
# Iteration 5; 370/469 	Minibatch Loss 0.013  Accuracy 100%
# Iteration 5; 380/469 	Minibatch Loss 0.058  Accuracy 98%
# Iteration 5; 390/469 	Minibatch Loss 0.042  Accuracy 98%
# Iteration 5; 400/469 	Minibatch Loss 0.058  Accuracy 98%
# Iteration 5; 410/469 	Minibatch Loss 0.040  Accuracy 98%
# Iteration 5; 420/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 5; 430/469 	Minibatch Loss 0.030  Accuracy 99%
# Iteration 5; 440/469 	Minibatch Loss 0.010  Accuracy 100%
# Iteration 5; 450/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 5; 460/469 	Minibatch Loss 0.029  Accuracy 98%
# Iteration 6; 0/469 	Minibatch Loss 0.091  Accuracy 98%
# Iteration 6; 10/469 	Minibatch Loss 0.054  Accuracy 98%
# Iteration 6; 20/469 	Minibatch Loss 0.148  Accuracy 97%
# Iteration 6; 30/469 	Minibatch Loss 0.033  Accuracy 99%
# Iteration 6; 40/469 	Minibatch Loss 0.009  Accuracy 100%
# Iteration 6; 50/469 	Minibatch Loss 0.003  Accuracy 100%
# Iteration 6; 60/469 	Minibatch Loss 0.014  Accuracy 100%
# Iteration 6; 70/469 	Minibatch Loss 0.023  Accuracy 99%
# Iteration 6; 80/469 	Minibatch Loss 0.084  Accuracy 98%
# Iteration 6; 90/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 6; 100/469 	Minibatch Loss 0.025  Accuracy 99%
# Iteration 6; 110/469 	Minibatch Loss 0.028  Accuracy 99%
# Iteration 6; 120/469 	Minibatch Loss 0.023  Accuracy 99%
# Iteration 6; 130/469 	Minibatch Loss 0.029  Accuracy 98%
# Iteration 6; 140/469 	Minibatch Loss 0.009  Accuracy 99%
# Iteration 6; 150/469 	Minibatch Loss 0.038  Accuracy 99%
# Iteration 6; 160/469 	Minibatch Loss 0.002  Accuracy 100%
# Iteration 6; 170/469 	Minibatch Loss 0.019  Accuracy 100%
# Iteration 6; 180/469 	Minibatch Loss 0.036  Accuracy 99%
# Iteration 6; 190/469 	Minibatch Loss 0.009  Accuracy 100%
# Iteration 6; 200/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 6; 210/469 	Minibatch Loss 0.017  Accuracy 100%
# Iteration 6; 220/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 6; 230/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 6; 240/469 	Minibatch Loss 0.044  Accuracy 98%
# Iteration 6; 250/469 	Minibatch Loss 0.015  Accuracy 99%
# Iteration 6; 260/469 	Minibatch Loss 0.023  Accuracy 99%
# Iteration 6; 270/469 	Minibatch Loss 0.016  Accuracy 99%
# Iteration 6; 280/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 6; 290/469 	Minibatch Loss 0.038  Accuracy 98%
# Iteration 6; 300/469 	Minibatch Loss 0.026  Accuracy 98%
# Iteration 6; 310/469 	Minibatch Loss 0.043  Accuracy 98%
# Iteration 6; 320/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 6; 330/469 	Minibatch Loss 0.058  Accuracy 98%
# Iteration 6; 340/469 	Minibatch Loss 0.035  Accuracy 99%
# Iteration 6; 350/469 	Minibatch Loss 0.059  Accuracy 98%
# Iteration 6; 360/469 	Minibatch Loss 0.026  Accuracy 98%
# Iteration 6; 370/469 	Minibatch Loss 0.071  Accuracy 98%
# Iteration 6; 380/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 6; 390/469 	Minibatch Loss 0.041  Accuracy 98%
# Iteration 6; 400/469 	Minibatch Loss 0.017  Accuracy 99%
# Iteration 6; 410/469 	Minibatch Loss 0.012  Accuracy 99%
# Iteration 6; 420/469 	Minibatch Loss 0.018  Accuracy 100%
# Iteration 6; 430/469 	Minibatch Loss 0.013  Accuracy 100%
# Iteration 6; 440/469 	Minibatch Loss 0.037  Accuracy 98%
# Iteration 6; 450/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 6; 460/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 7; 0/469 	Minibatch Loss 0.036  Accuracy 98%
# Iteration 7; 10/469 	Minibatch Loss 0.028  Accuracy 98%
# Iteration 7; 20/469 	Minibatch Loss 0.020  Accuracy 100%
# Iteration 7; 30/469 	Minibatch Loss 0.016  Accuracy 100%
# Iteration 7; 40/469 	Minibatch Loss 0.060  Accuracy 98%
# Iteration 7; 50/469 	Minibatch Loss 0.041  Accuracy 98%
# Iteration 7; 60/469 	Minibatch Loss 0.013  Accuracy 99%
# Iteration 7; 70/469 	Minibatch Loss 0.013  Accuracy 100%
# Iteration 7; 80/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 7; 90/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 7; 100/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 7; 110/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 7; 120/469 	Minibatch Loss 0.028  Accuracy 99%
# Iteration 7; 130/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 7; 140/469 	Minibatch Loss 0.016  Accuracy 99%
# Iteration 7; 150/469 	Minibatch Loss 0.018  Accuracy 99%
# Iteration 7; 160/469 	Minibatch Loss 0.038  Accuracy 99%
# Iteration 7; 170/469 	Minibatch Loss 0.027  Accuracy 99%
# Iteration 7; 180/469 	Minibatch Loss 0.023  Accuracy 99%
# Iteration 7; 190/469 	Minibatch Loss 0.018  Accuracy 99%
# Iteration 7; 200/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 7; 210/469 	Minibatch Loss 0.010  Accuracy 100%
# Iteration 7; 220/469 	Minibatch Loss 0.014  Accuracy 100%
# Iteration 7; 230/469 	Minibatch Loss 0.031  Accuracy 98%
# Iteration 7; 240/469 	Minibatch Loss 0.014  Accuracy 99%
# Iteration 7; 250/469 	Minibatch Loss 0.009  Accuracy 100%
# Iteration 7; 260/469 	Minibatch Loss 0.018  Accuracy 99%
# Iteration 7; 270/469 	Minibatch Loss 0.031  Accuracy 99%
# Iteration 7; 280/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 7; 290/469 	Minibatch Loss 0.014  Accuracy 100%
# Iteration 7; 300/469 	Minibatch Loss 0.031  Accuracy 99%
# Iteration 7; 310/469 	Minibatch Loss 0.032  Accuracy 99%
# Iteration 7; 320/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 7; 330/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 7; 340/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 7; 350/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 7; 360/469 	Minibatch Loss 0.028  Accuracy 99%
# Iteration 7; 370/469 	Minibatch Loss 0.025  Accuracy 98%
# Iteration 7; 380/469 	Minibatch Loss 0.059  Accuracy 99%
# Iteration 7; 390/469 	Minibatch Loss 0.010  Accuracy 99%
# Iteration 7; 400/469 	Minibatch Loss 0.053  Accuracy 98%
# Iteration 7; 410/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 7; 420/469 	Minibatch Loss 0.016  Accuracy 99%
# Iteration 7; 430/469 	Minibatch Loss 0.033  Accuracy 99%
# Iteration 7; 440/469 	Minibatch Loss 0.042  Accuracy 99%
# Iteration 7; 450/469 	Minibatch Loss 0.038  Accuracy 98%
# Iteration 7; 460/469 	Minibatch Loss 0.050  Accuracy 98%
# Iteration 8; 0/469 	Minibatch Loss 0.050  Accuracy 99%
# Iteration 8; 10/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 8; 20/469 	Minibatch Loss 0.027  Accuracy 99%
# Iteration 8; 30/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 8; 40/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 8; 50/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 8; 60/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 8; 70/469 	Minibatch Loss 0.033  Accuracy 98%
# Iteration 8; 80/469 	Minibatch Loss 0.030  Accuracy 98%
# Iteration 8; 90/469 	Minibatch Loss 0.021  Accuracy 99%
# Iteration 8; 100/469 	Minibatch Loss 0.029  Accuracy 98%
# Iteration 8; 110/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 8; 120/469 	Minibatch Loss 0.015  Accuracy 100%
# Iteration 8; 130/469 	Minibatch Loss 0.040  Accuracy 97%
# Iteration 8; 140/469 	Minibatch Loss 0.028  Accuracy 99%
# Iteration 8; 150/469 	Minibatch Loss 0.029  Accuracy 98%
# Iteration 8; 160/469 	Minibatch Loss 0.017  Accuracy 100%
# Iteration 8; 170/469 	Minibatch Loss 0.028  Accuracy 99%
# Iteration 8; 180/469 	Minibatch Loss 0.028  Accuracy 99%
# Iteration 8; 190/469 	Minibatch Loss 0.181  Accuracy 98%
# Iteration 8; 200/469 	Minibatch Loss 0.020  Accuracy 100%
# Iteration 8; 210/469 	Minibatch Loss 0.045  Accuracy 98%
# Iteration 8; 220/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 8; 230/469 	Minibatch Loss 0.015  Accuracy 99%
# Iteration 8; 240/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 8; 250/469 	Minibatch Loss 0.013  Accuracy 100%
# Iteration 8; 260/469 	Minibatch Loss 0.023  Accuracy 100%
# Iteration 8; 270/469 	Minibatch Loss 0.088  Accuracy 98%
# Iteration 8; 280/469 	Minibatch Loss 0.010  Accuracy 100%
# Iteration 8; 290/469 	Minibatch Loss 0.035  Accuracy 98%
# Iteration 8; 300/469 	Minibatch Loss 0.043  Accuracy 98%
# Iteration 8; 310/469 	Minibatch Loss 0.021  Accuracy 99%
# Iteration 8; 320/469 	Minibatch Loss 0.031  Accuracy 98%
# Iteration 8; 330/469 	Minibatch Loss 0.043  Accuracy 98%
# Iteration 8; 340/469 	Minibatch Loss 0.069  Accuracy 97%
# Iteration 8; 350/469 	Minibatch Loss 0.023  Accuracy 99%
# Iteration 8; 360/469 	Minibatch Loss 0.009  Accuracy 100%
# Iteration 8; 370/469 	Minibatch Loss 0.014  Accuracy 100%
# Iteration 8; 380/469 	Minibatch Loss 0.014  Accuracy 100%
# Iteration 8; 390/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 8; 400/469 	Minibatch Loss 0.035  Accuracy 98%
# Iteration 8; 410/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 8; 420/469 	Minibatch Loss 0.056  Accuracy 98%
# Iteration 8; 430/469 	Minibatch Loss 0.053  Accuracy 98%
# Iteration 8; 440/469 	Minibatch Loss 0.049  Accuracy 99%
# Iteration 8; 450/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 8; 460/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 9; 0/469 	Minibatch Loss 0.011  Accuracy 99%
# Iteration 9; 10/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 9; 20/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 9; 30/469 	Minibatch Loss 0.046  Accuracy 98%
# Iteration 9; 40/469 	Minibatch Loss 0.019  Accuracy 98%
# Iteration 9; 50/469 	Minibatch Loss 0.004  Accuracy 100%
# Iteration 9; 60/469 	Minibatch Loss 0.012  Accuracy 100%
# Iteration 9; 70/469 	Minibatch Loss 0.043  Accuracy 99%
# Iteration 9; 80/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 9; 90/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 9; 100/469 	Minibatch Loss 0.010  Accuracy 99%
# Iteration 9; 110/469 	Minibatch Loss 0.074  Accuracy 98%
# Iteration 9; 120/469 	Minibatch Loss 0.071  Accuracy 98%
# Iteration 9; 130/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 9; 140/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 9; 150/469 	Minibatch Loss 0.031  Accuracy 99%
# Iteration 9; 160/469 	Minibatch Loss 0.034  Accuracy 99%
# Iteration 9; 170/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 9; 180/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 9; 190/469 	Minibatch Loss 0.030  Accuracy 99%
# Iteration 9; 200/469 	Minibatch Loss 0.018  Accuracy 100%
# Iteration 9; 210/469 	Minibatch Loss 0.050  Accuracy 99%
# Iteration 9; 220/469 	Minibatch Loss 0.006  Accuracy 100%
# Iteration 9; 230/469 	Minibatch Loss 0.010  Accuracy 100%
# Iteration 9; 240/469 	Minibatch Loss 0.030  Accuracy 98%
# Iteration 9; 250/469 	Minibatch Loss 0.049  Accuracy 98%
# Iteration 9; 260/469 	Minibatch Loss 0.033  Accuracy 99%
# Iteration 9; 270/469 	Minibatch Loss 0.004  Accuracy 100%
# Iteration 9; 280/469 	Minibatch Loss 0.048  Accuracy 99%
# Iteration 9; 290/469 	Minibatch Loss 0.019  Accuracy 99%
# Iteration 9; 300/469 	Minibatch Loss 0.049  Accuracy 98%
# Iteration 9; 310/469 	Minibatch Loss 0.014  Accuracy 99%
# Iteration 9; 320/469 	Minibatch Loss 0.033  Accuracy 98%
# Iteration 9; 330/469 	Minibatch Loss 0.027  Accuracy 98%
# Iteration 9; 340/469 	Minibatch Loss 0.052  Accuracy 98%
# Iteration 9; 350/469 	Minibatch Loss 0.007  Accuracy 100%
# Iteration 9; 360/469 	Minibatch Loss 0.115  Accuracy 97%
# Iteration 9; 370/469 	Minibatch Loss 0.039  Accuracy 98%
# Iteration 9; 380/469 	Minibatch Loss 0.011  Accuracy 100%
# Iteration 9; 390/469 	Minibatch Loss 0.034  Accuracy 99%
# Iteration 9; 400/469 	Minibatch Loss 0.033  Accuracy 99%
# Iteration 9; 410/469 	Minibatch Loss 0.037  Accuracy 98%
# Iteration 9; 420/469 	Minibatch Loss 0.025  Accuracy 99%
# Iteration 9; 430/469 	Minibatch Loss 0.048  Accuracy 99%
# Iteration 9; 440/469 	Minibatch Loss 0.008  Accuracy 100%
# Iteration 9; 450/469 	Minibatch Loss 0.020  Accuracy 99%
# Iteration 9; 460/469 	Minibatch Loss 0.005  Accuracy 100%
# saving model at: MNIST_weights.pth

# %%
#predict in distribution
MNIST_PATH = "MNIST_weights.pth"

mnist_model = NN(num_classes=10)
print("loading model from: {}".format(MNIST_PATH))
mnist_model.load_state_dict(torch.load(MNIST_PATH))
mnist_model.eval()

acc = []

max_len = len(mnist_test_loader)
for batch_idx, (x, y) in enumerate(mnist_test_loader):
        output = mnist_model(x)
        accuracy = get_accuracy(output, y)
        if batch_idx % 10 == 0:
            print(
                "Batch {}/{} \t".format(batch_idx, max_len) + 
                "Accuracy %.0f" % (accuracy * 100) + "%"
            )
        acc.append(accuracy)
    
avg_acc = np.mean(acc)
print('overall test accuracy on MNIST: {:.02f} %'.format(avg_acc * 100))
# Out:
# loading model from: MNIST_weights.pth
# Batch 0/79 	Accuracy 100%
# Batch 10/79 	Accuracy 97%
# Batch 20/79 	Accuracy 98%
# Batch 30/79 	Accuracy 98%
# Batch 40/79 	Accuracy 100%
# Batch 50/79 	Accuracy 100%
# Batch 60/79 	Accuracy 100%
# Batch 70/79 	Accuracy 100%
# overall test accuracy on MNIST: 99.13 %

# %% [markdown]
# # Laplace approximation of the weights
# - we use the BackPACK package to approximate the Hessian of the parameters. Especially look at the DiagHessian() method.
# - we do one iteration over the entire training set and use the mean of the Hessian of the mini-batches as the best approximation of the Hessian.
# - we add a prior variance to our Hessian. The precision is 1 over the variance. we use a prior precision of 10, 20, and 50 (or variance of 1/10, 1/20, 1/50).

# %%
def get_Hessian_NN(model, train_loader, prec0, device='cpu', verbose=True):
    lossfunc = torch.nn.CrossEntropyLoss()

    extend(lossfunc, debug=False)
    extend(model, debug=False)

    Hessian_diag = []
    for param in model.parameters():
        ps = param.size()
        print("parameter size: ", ps)
        Hessian_diag.append(torch.zeros(ps, device=device))
        #print(param.numel())

    var0 = 1/prec0
    max_len = len(train_loader)

    with backpack(DiagHessian()):

        for batch_idx, (x, y) in enumerate(train_loader):

            if device == 'cuda':
                x, y = x.float().cuda(), y.long().cuda()

            model.zero_grad()
            lossfunc(model(x), y).backward()

            with torch.no_grad():
                # Hessian of weight
                for idx, param in enumerate(model.parameters()):

                    H_ = param.diag_h
                    #add prior here
                    H_ += var0 * torch.ones(H_.size())

                    rho = 1-1/(batch_idx+1)

                    Hessian_diag[idx] = rho*Hessian_diag[idx] + (1-rho)* H_
            
            if verbose:
                print("Batch: {}/{}".format(batch_idx, max_len))
    
    return(Hessian_diag)

# %%
MNIST_NN_Hessian_diag_10 = get_Hessian_NN(model=mnist_model, train_loader=mnist_train_loader, prec0=10,verbose=False)
# Out:
# parameter size:  torch.Size([32, 1, 5, 5])
# parameter size:  torch.Size([32])
# parameter size:  torch.Size([32, 32, 5, 5])
# parameter size:  torch.Size([32])
# parameter size:  torch.Size([10, 512])
# parameter size:  torch.Size([10])

# %%
MNIST_NN_Hessian_diag_20 = get_Hessian_NN(model=mnist_model, train_loader=mnist_train_loader, prec0=20,verbose=False)
# Out:
# parameter size:  torch.Size([32, 1, 5, 5])
# parameter size:  torch.Size([32])
# parameter size:  torch.Size([32, 32, 5, 5])
# parameter size:  torch.Size([32])
# parameter size:  torch.Size([10, 512])
# parameter size:  torch.Size([10])

# %%
MNIST_NN_Hessian_diag_50 = get_Hessian_NN(model=mnist_model, train_loader=mnist_train_loader, prec0=50,verbose=False)
# Out:
# parameter size:  torch.Size([32, 1, 5, 5])
# parameter size:  torch.Size([32])
# parameter size:  torch.Size([32, 32, 5, 5])
# parameter size:  torch.Size([32])
# parameter size:  torch.Size([10, 512])
# parameter size:  torch.Size([10])

# %%
print(MNIST_NN_Hessian_diag_50)
# Out:
# [tensor([[[[0.0208, 0.0208, 0.0207, 0.0206, 0.0205],
#           [0.0207, 0.0207, 0.0206, 0.0205, 0.0204],
#           [0.0206, 0.0207, 0.0206, 0.0205, 0.0204],
#           [0.0206, 0.0207, 0.0206, 0.0204, 0.0203],
#           [0.0207, 0.0208, 0.0206, 0.0204, 0.0203]]],
#           [0.0201, 0.0202, 0.0201, 0.0201, 0.0200],
#           [0.0201, 0.0201, 0.0201, 0.0200, 0.0200],
#           [0.0201, 0.0201, 0.0201, 0.0200, 0.0200]],
#
#          [[0.0206, 0.0208, 0.0207, 0.0208, 0.0208],
#           [0.0206, 0.0207, 0.0213, 0.0214, 0.0209],
#           [0.0205, 0.0211, 0.0224, 0.0216, 0.0205],
#           [0.0207, 0.0223, 0.0224, 0.0207, 0.0202],
#           [0.0211, 0.0221, 0.0211, 0.0202, 0.0204]],
#
#          ...,
#
#          [[0.0202, 0.0202, 0.0202, 0.0203, 0.0203],
#           [0.0203, 0.0203, 0.0204, 0.0204, 0.0202],
#           [0.0202, 0.0204, 0.0204, 0.0202, 0.0201],
#           [0.0205, 0.0205, 0.0202, 0.0201, 0.0201],
#           [0.0204, 0.0202, 0.0201, 0.0202, 0.0202]],
#
#          [[0.0204, 0.0205, 0.0206, 0.0204, 0.0202],
#           [0.0204, 0.0204, 0.0207, 0.0209, 0.0209],
#           [0.0206, 0.0203, 0.0203, 0.0205, 0.0207],
#           [0.0204, 0.0203, 0.0203, 0.0203, 0.0202],
#           [0.0206, 0.0206, 0.0204, 0.0202, 0.0202]],
#
#          [[0.0202, 0.0202, 0.0203, 0.0203, 0.0202],
#           [0.0203, 0.0203, 0.0202, 0.0202, 0.0203],
#           [0.0204, 0.0204, 0.0201, 0.0201, 0.0203],
#           [0.0204, 0.0203, 0.0201, 0.0201, 0.0203],
#           [0.0204, 0.0202, 0.0201, 0.0201, 0.0202]]]]), tensor([0.0206, 0.0221, 0.0223, 0.0208, 0.0208, 0.0205, 0.0200, 0.0205, 0.0210,
#         0.0228, 0.0215, 0.0205, 0.0205, 0.0205, 0.0204, 0.0210, 0.0213, 0.0209,
#         0.0204, 0.0209, 0.0200, 0.0211, 0.0200, 0.0208, 0.0206, 0.0207, 0.0211,
#         0.0207, 0.0219, 0.0205, 0.0206, 0.0211]), tensor([[0.0205, 0.0225, 0.0249,  ..., 0.0203, 0.0234, 0.0227],
#         [0.0212, 0.0238, 0.0233,  ..., 0.0222, 0.0216, 0.0208],
#         [0.0217, 0.0257, 0.0289,  ..., 0.0221, 0.0228, 0.0219],
#         ...,
#         [0.0218, 0.0251, 0.0258,  ..., 0.0270, 0.0268, 0.0215],
#         [0.0228, 0.0261, 0.0315,  ..., 0.0231, 0.0266, 0.0298],
#         [0.0222, 0.0280, 0.0331,  ..., 0.0280, 0.0308, 0.0246]]), tensor([0.0209, 0.0212, 0.0218, 0.0219, 0.0218, 0.0216, 0.0211, 0.0218, 0.0222,
#         0.0226])]

# %% [markdown]
# # Plot the results
# - We take the first ten datapoints from the test dataset.
# - Draw 100 samples from the weight distribution do a forward pass for each and plot the resulting predictions.
# - Repeat this procedure for prior precision 10, 20 and 50 (or variance of 1/10, 1/20, 1/50).

# %%
#get the first ten datapoints from the test set
mnist_test_loader_10 = torch.utils.data.dataloader.DataLoader(
    MNIST_test,
    batch_size=10,
    shuffle=False,
)

test_10_X, test_10_y = next(iter(mnist_test_loader_10))
print(test_10_X.size(), test_10_y.size())
print(test_10_y)
# Out:
# torch.Size([10, 1, 28, 28]) torch.Size([10])
# tensor([7, 2, 1, 0, 4, 1, 4, 9, 5, 9])

# %%
#take 100 samples from the distribution over the weights. 

def get_param_dists(Hessian):
    param_dists = []
    for idx, param in enumerate(mnist_model.parameters()):
        ps = param.size()
        mu = param.view(-1)
        Sigma = Hessian[idx].view(-1)
        print("mu size: ", mu.size())
        print("Sigma size: ", Sigma.size())
        dist = Normal(mu, Sigma)
        param_dists.append(dist)
        
    return(param_dists)

# %%
param_dists_10 = get_param_dists(MNIST_NN_Hessian_diag_10)
param_dists_20 = get_param_dists(MNIST_NN_Hessian_diag_20)
param_dists_50 = get_param_dists(MNIST_NN_Hessian_diag_50)
# Out:
# mu size:  torch.Size([800])
# Sigma size:  torch.Size([800])
# mu size:  torch.Size([32])
# Sigma size:  torch.Size([32])
# mu size:  torch.Size([25600])
# Sigma size:  torch.Size([25600])
# mu size:  torch.Size([32])
# Sigma size:  torch.Size([32])
# mu size:  torch.Size([5120])
# Sigma size:  torch.Size([5120])
# mu size:  torch.Size([10])
# Sigma size:  torch.Size([10])
# mu size:  torch.Size([800])
# Sigma size:  torch.Size([800])
# mu size:  torch.Size([32])
# Sigma size:  torch.Size([32])
# mu size:  torch.Size([25600])
# Sigma size:  torch.Size([25600])
# mu size:  torch.Size([32])
# Sigma size:  torch.Size([32])
# mu size:  torch.Size([5120])
# Sigma size:  torch.Size([5120])
# mu size:  torch.Size([10])
# Sigma size:  torch.Size([10])
# mu size:  torch.Size([800])
# Sigma size:  torch.Size([800])
# mu size:  torch.Size([32])
# Sigma size:  torch.Size([32])
# mu size:  torch.Size([25600])
# Sigma size:  torch.Size([25600])
# mu size:  torch.Size([32])
# Sigma size:  torch.Size([32])
# mu size:  torch.Size([5120])
# Sigma size:  torch.Size([5120])
# mu size:  torch.Size([10])
# Sigma size:  torch.Size([10])

# %%
def get_stacked_results(param_dists, input_):

    num_samples = 100
    results = []

    mnist_test_model = NN(num_classes=10)
    mnist_test_model.eval()
    #new_state_dict = fmnist_model.state_dict()
    new_state_dict = dict()
    for s in range(num_samples):
        #torch.manual_seed(s)
        for idx, (p_name, param) in enumerate(mnist_model.named_parameters()):
            ps = param.size()
            new_weights = param_dists[idx].sample().view(ps)
            new_state_dict[p_name] = new_weights

        #print(new_state_dict.keys())
        mnist_test_model.load_state_dict(new_state_dict)
        y_pred_logits = mnist_test_model(input_)
        #print(y_pred_logits)
        y_pred = F.softmax(y_pred_logits, dim=1) 
        results.append(y_pred)

    stacked_results = torch.stack(results)
    return(stacked_results)

# %%
stacked_results_10 = get_stacked_results(param_dists_10, input_=test_10_X)
stacked_results_20 = get_stacked_results(param_dists_20, input_=test_10_X)
stacked_results_50 = get_stacked_results(param_dists_50, input_=test_10_X)

# %%
def plot_results_singular(stacked_results, num_bins=10, idx=0):

    for j in range(10):
        plt.hist(stacked_results[:,idx,j].detach().numpy(), range=[0,1], \
                           bins=num_bins, alpha=0.5, label='{}'.format(j))
        plt.legend()
        
    plt.show();

# %% [markdown]
# ### plot singular results

# %%
plot_results_singular(stacked_results_10, idx=0, num_bins=20)

# %%
plot_results_singular(stacked_results_20, idx=0, num_bins=20)

# %%
plot_results_singular(stacked_results_50, idx=0, num_bins=50)

# %% [markdown]
# ### plot multiple results

# %%
def plot_results_multiple(stacked_results, num_bins=10):
    fig, axs = plt.subplots(nrows=2, ncols=5, sharex=False, figsize=(26,6))

    for i in range(10):
        x = i // 5
        y = i % 5
        for j in range(10):
            axs[x][y].hist(stacked_results[:,i,j].detach().numpy(), range=[0,1], \
                           bins=num_bins, alpha=0.5, label='{}'.format(j))
            axs[x][y].legend()
        
    plt.show();

# %%
#plot the results for prior precision 10

plot_results_multiple(stacked_results_10)

# %%
#plot the results for prior precision 20

plot_results_multiple(stacked_results_20, num_bins=20)

# %%
#plot the results for prior precision 50

plot_results_multiple(stacked_results_50, num_bins=50)

# %% [markdown]
# # Why be Bayesian?

# %% [markdown]
# In this section we will test what the model does with data that do not belong to the distribution it was trained on (also known as out-of-distribution (OOD) data).
# 1. We will look at some numbers. AUROC, MMC, entropy, etc.
# 2. We test how results for a scaled version of MNIST look like
# 3. We test how results for White Noise look like
# 4. We test how results for Fashion MNIST look like

# %%
def get_in_dist_values(py_in, targets):
    acc_in = np.mean(np.argmax(py_in, 1) == targets)
    prob_correct = py_in[targets].mean()
    average_entropy = -np.sum(py_in*np.log(py_in+1e-8), axis=1).mean()
    MMC = py_in.max(1).mean()
    return(acc_in, prob_correct, average_entropy, MMC)

def get_out_dist_values(py_in, py_out, targets):
    average_entropy = -np.sum(py_out*np.log(py_out+1e-8), axis=1).mean()
    acc_out = np.mean(np.argmax(py_out, 1) == targets)
    if max(targets) > len(py_in[0]):
        targets = np.array(targets)
        targets[targets >= len(py_in[0])] = 0
    prob_correct = py_out[targets].mean()
    labels = np.zeros(len(py_in)+len(py_out), dtype='int32')
    labels[:len(py_in)] = 1
    examples = np.concatenate([py_in.max(1), py_out.max(1)])
    auroc = roc_auc_score(labels, examples)
    MMC = py_out.max(1).mean()
    return(acc_out, prob_correct, average_entropy, MMC, auroc)

def print_in_dist_values(acc_in, prob_correct, average_entropy, MMC, train='mnist', method='KFAC'):

    print(f'[In, {method}, {train}] Accuracy: {acc_in:.3f}; average entropy: {average_entropy:.3f}; \
    MMC: {MMC:.3f}; Prob @ correct: {prob_correct:.3f}')


def print_out_dist_values(acc_out, prob_correct, average_entropy, MMC, auroc, train='mnist', test='FMNIST', method='KFAC'):

    print(f'[Out-{test}, {method}, {train}] Accuracy: {acc_out:.3f}; Average entropy: {average_entropy:.3f};\
    MMC: {MMC:.3f}; AUROC: {auroc:.3f}; Prob @ correct: {prob_correct:.3f}')

# %%
#set up Some FMNIST images
FMNIST_test = torchvision.datasets.FashionMNIST(
        '~/data/fmnist',
        train=False,
        download=False,
        transform=MNIST_transform)

fmnist_test_loader = torch.utils.data.dataloader.DataLoader(
    FMNIST_test,
    batch_size=10,
    shuffle=False,
)

FMNIST_test_10_X, FMNIST_test_10_y = next(iter(fmnist_test_loader))
print(FMNIST_test_10_X.size(), FMNIST_test_10_y.size())
print(FMNIST_test_10_y)

FMNIST_images = FMNIST_test.data[:10].view(10, 1, 28, 28)
imshow(torchvision.utils.make_grid(FMNIST_images, nrow=5))
# Out:
# torch.Size([10, 1, 28, 28]) torch.Size([10])
# tensor([9, 2, 1, 1, 6, 1, 4, 6, 5, 7])

# %%
from sklearn.metrics import roc_auc_score
targets = FMNIST_test.targets.numpy()

# %%
MNIST_in = []
for x,y in mnist_test_loader:
    out_ = mnist_model(x).detach()
    out = F.softmax(out_, dim=1) 
    MNIST_in.append(out)
MNIST_in = torch.cat(MNIST_in, dim=0).cpu().numpy()

# %%
FMNIST_out = []
for x,y in fmnist_test_loader:
    out_ = mnist_model(x).detach()
    out = F.softmax(out_, dim=1) 
    FMNIST_out.append(out)
FMNIST_out = torch.cat(FMNIST_out, dim=0).cpu().numpy()

# %%
acc_FMNIST, prob_FMNIST, ent_FMNIST, MMC_FMNIST, auroc_FMNIST = get_out_dist_values(MNIST_in, FMNIST_out, targets)
print_out_dist_values(acc_FMNIST, prob_FMNIST, ent_FMNIST, MMC_FMNIST, auroc_FMNIST, method='MAP')
# Out:
# [Out-FMNIST, MAP, mnist] Accuracy: 0.064; Average entropy: 1.224;    MMC: 0.564; AUROC: 0.988; Prob @ correct: 0.100

# %% [markdown]
# ## Scaled MNIST tests

# %%
# set up some scaled FMNIST images
mnist_test_loader_10 = torch.utils.data.dataloader.DataLoader(
    MNIST_test,
    batch_size=10,
    shuffle=False,
)

MNIST_test_10_X, MNIST_test_10_y = next(iter(mnist_test_loader_10))
MNIST_test_10_X_scaled = 1000 * MNIST_test_10_X
print(MNIST_test_10_X_scaled.size())

MNIST_images = MNIST_test_10_X_scaled.view(10, 1, 28, 28)
imshow(torchvision.utils.make_grid(MNIST_images, nrow=5))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([10, 1, 28, 28])

# %%
MNIST_stacked_results_10_scaled = get_stacked_results(param_dists_10, input_=MNIST_test_10_X_scaled)
plot_results_multiple(MNIST_stacked_results_10_scaled)

# %% [markdown]
# ## White noise test

# %%
# set up some white noise images
white_noise_10 = torch.empty((10,1,28,28)).normal_(mean=0,std=1)
imshow(torchvision.utils.make_grid(white_noise_10, nrow=5))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
WN_stacked_results_10 = get_stacked_results(param_dists_10, input_=white_noise_10)
plot_results_multiple(WN_stacked_results_10, num_bins=10)

# %%
WN_stacked_results_20 = get_stacked_results(param_dists_20, input_=white_noise_10)
plot_results_multiple(WN_stacked_results_20, num_bins=20)

# %%
WN_stacked_results_20 = get_stacked_results(param_dists_20, input_=white_noise_10)
plot_results_multiple(WN_stacked_results_20, num_bins=20)

# %% [markdown]
# ## FMNIST OOD test

# %%
FMNIST_stacked_results_10 = get_stacked_results(param_dists_10, input_=FMNIST_test_10_X)
plot_results_multiple(FMNIST_stacked_results_10)

# %%
FMNIST_stacked_results_20 = get_stacked_results(param_dists_20, input_=FMNIST_test_10_X)
plot_results_multiple(FMNIST_stacked_results_20, num_bins=20)

# %%
FMNIST_stacked_results_50 = get_stacked_results(param_dists_50, input_=FMNIST_test_10_X)
plot_results_multiple(FMNIST_stacked_results_50, num_bins=50)
